# %%
###AUDIO SENTIMENT ANALYSIS

# %%
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import sklearn.metrics as skm
import sklearn.model_selection as skms
import sklearn.preprocessing as skp
import random, os
import librosa, IPython
import librosa.display as lplt
from skimage.io import imread
seed = 12
np.random.seed(seed)

# %%
trainPath = '/content/drive/MyDrive/sentiment classification data/TRAIN/'
testPath = '/content/drive/MyDrive/sentiment classification data/TEST/'
df_base = pd.read_csv('/content/drive/MyDrive/sentiment classification data/TRAIN.csv')
df_base.head()
# Out:
#   Filename     Class
# 0  346.wav  Negative
# 1  163.wav   Neutral
# 2  288.wav  Negative
# 3  279.wav  Negative
# 4  244.wav  Negative

# %%
print("Dataset has",df_base.shape[0],"samples")
print("Count of Positive and Negative samples")
df_base['Class'].value_counts().reset_index()
# Out:
# Dataset has 250 samples
# Count of Positive and Negative samples
#       Class  count
# 0  Negative     87
# 1  Positive     82
# 2   Neutral     81

# %%
sample_rate = 44100
def loadAudio(fp):
    return librosa.load(fp, res_type='kaiser_fast', duration=2.5, offset=0.5, sr=sample_rate)

# %%
def scanFeatures(path, avgFeat=0):
    features = []
    minFeat = sys.maxsize
    maxFeat = 0
    files = sorted(os.listdir(path))
    print("Scanning", path)

    for i, fp in enumerate(files):
        X, sr = loadAudio(os.path.join(path, fp))

        f = librosa.feature.melspectrogram(y=X, sr=sample_rate)
        f = librosa.amplitude_to_db(f, ref=np.max)

        shapeY = f.shape[1]
        if shapeY < minFeat:
            minFeat = shapeY

        if shapeY > maxFeat:
            maxFeat = shapeY

        features.append(f)
    if avgFeat == 0:
        avgFeat = int((minFeat+maxFeat)/2)
    feat_mat = np.zeros((len(files), f.shape[0], avgFeat))
    for i, x in enumerate(features):
        xWidth = min(x.shape[1],avgFeat)
        feat_mat[i, :, :xWidth] = x[:,:xWidth]
    return feat_mat, files

# %%
f_dim = 128
train_data, train_files = scanFeatures(trainPath, f_dim)
test_data, test_files = scanFeatures(testPath, train_data.shape[1])
print(train_data.shape)
print(test_data.shape)
# Out:
# Scanning /content/drive/MyDrive/sentiment classification data/TRAIN/
# Scanning /content/drive/MyDrive/sentiment classification data/TEST/
# (250, 128, 128)
# (110, 128, 128)

# %%
def saveImg(f, fp):
    f = np.flip(f, axis=0)
    plt.figure()
    plt.axis('off')
    plt.imsave(fp, f, format='png')
    plt.clf()

# %%
###SAVING FEATURE TO IMAGE

# %%
def saveFeatureToImage(path, saveDir, avgFeat=0):
    global sample_rate
    files = sorted(os.listdir(path))
    print("Scanning", path)

    for i, fp in enumerate(files):
        X, sr = loadAudio(os.path.join(path, fp))

        f = librosa.feature.melspectrogram(y=X, sr=sample_rate)
        f = librosa.amplitude_to_db(f, ref=np.max)

        img = np.zeros((f.shape[0], avgFeat))
        xWidth = min(f.shape[1],avgFeat)
        img[:, :xWidth] = f[:,:xWidth]
        fname = os.path.join(saveDir, fp.split('.')[0] + '.png')
        saveImg(img, fname)

# %%
f_dim = 128
train_img_dir = './train_images'
test_img_dir = './test_images'
if not os.path.exists(train_img_dir):
    os.mkdir(train_img_dir)
    saveFeatureToImage(trainPath, train_img_dir, f_dim)
if not os.path.exists(test_img_dir):
    os.mkdir(test_img_dir)
    saveFeatureToImage(testPath, test_img_dir, train_data.shape[1])
# Out:
# Scanning /content/drive/MyDrive/sentiment classification data/TRAIN/
# Scanning /content/drive/MyDrive/sentiment classification data/TEST/

# %%
def scanImgFeatures(path):
    features = []
    files = sorted(os.listdir(path))
    for x in files:
        fp = os.path.join(path, x)
        img = imread(fp)[:,:,:3]/255.0
        features.append(img)
    return np.array(features), files

# %%
if os.path.exists(train_img_dir):
    train_data_img, train_files_img = scanImgFeatures(train_img_dir)
if os.path.exists(test_img_dir):
    test_data_img, test_files_img = scanImgFeatures(test_img_dir)
    plt.imshow(test_data_img[0])
    plt.show()

# %%
def getPathLabels(p):
    return [df_base[df_base['Filename'] == x].iloc[0,1] for x in p]

# %%
train_labels = getPathLabels(train_files)

# %%
audio_fp = '/content/drive/MyDrive/sentiment classification data/TRAIN/10.wav'
audio_data, sr = loadAudio(audio_fp)
audio_data, _ = librosa.effects.trim(audio_data)

# %%
# play sample file
IPython.display.Audio(audio_data, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15, 5))
plt.plot(np.arange(len(audio_data)) / sr, audio_data)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Audio Waveform')
plt.show()

# %%
 #Default FFT window size
n_fft = 2048 # window size
hop_length = 512 # window hop length for STFT

stft = librosa.stft(audio_data, n_fft=n_fft, hop_length=hop_length)
stft_db = librosa.amplitude_to_db(stft, ref=np.max)

plt.figure(figsize=(12,4))
lplt.specshow(stft, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()
plt.title("Spectrogram with amplitude")
plt.show()

plt.figure(figsize=(12,4))
lplt.specshow(stft_db, sr=sr, x_axis='time', y_axis='log', cmap='cool')
plt.colorbar()
plt.title("Spectrogram with decibel log")
plt.show()

# %%
###DATA PREPARATION

# %%
# map labels to index
label_index = dict()
index_label = dict()
for i, x in enumerate(df_base['Class'].unique()):
    label_index[x] = i
    index_label[i] = x
print(label_index)
print(index_label)
# Out:
# {'Negative': 0, 'Neutral': 1, 'Positive': 2}
# {0: 'Negative', 1: 'Neutral', 2: 'Positive'}

# %%
# update labels in df to index
train_labels_idx = [label_index[l] for l in train_labels]
train_labels_idx[::10]
# Out:
# [2, 2, 2, 1, 1, 1, 2, 1, 1, 1, 1, 1, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 2, 2, 2]

# %%
df_shuffle = df_base.sample(frac=1, random_state=seed).reset_index(drop=True)

# %%
# remove irrelevant columns
df_shuffle.drop(['Filename'], axis=1, inplace=True)
df_y = df_shuffle.pop('Class')

# split into train dev and test
y_train, y_test = skms.train_test_split(df_y, train_size=0.8, random_state=seed, stratify=df_y)

# %%
print(f"Train set has {y_train.shape[0]} records out of {len(df_shuffle)} which is {round(y_train.shape[0]/len(df_shuffle)*100)}%")
print(f"Test set has {y_test.shape[0]} records out of {len(df_shuffle)} which is {round(y_test.shape[0]/len(df_shuffle)*100)}%")
# Out:
# Train set has 200 records out of 250 which is 80%
# Test set has 50 records out of 250 which is 20%

# %%
# stratified split check
print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# Class
# Negative    69
# Positive    66
# Neutral     65
# Name: count, dtype: int64
# Class
# Negative    18
# Neutral     16
# Positive    16
# Name: count, dtype: int64

# %%
# divide train_data into X_train and X_test
X_train = train_data[y_train.index.tolist(), :, :]
X_test = train_data[y_test.index.tolist(), :, :]
X_test.shape
# Out:
# (50, 128, 128)

# %%
y_train = np.array([train_labels_idx[x] for x in y_train.index.tolist()])
y_test = np.array([train_labels_idx[x] for x in y_test.index.tolist()])
y_train[::10]
# Out:
# array([1, 2, 2, 2, 2, 0, 2, 0, 1, 1, 1, 1, 2, 0, 0, 2, 1, 0, 0, 2])

# %%
# scale features
scaler = skp.MinMaxScaler()
X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
test_data = scaler.transform(test_data.reshape(-1, test_data.shape[-1])).reshape(test_data.shape)
print(X_train.shape)
# Out:
# (200, 128, 128)

# %%
# Model Building

# %%
import tensorflow as tf
print("TF version:-", tf.__version__)
import keras as k
from keras import backend as K
tf.random.set_seed(seed)
# Out:
# TF version:- 2.15.0

# %%
bestModelPath = './best_model.hdf5'
ACCURACY_THRESHOLD = 0.98

class myCallback(k.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('val_accuracy') > ACCURACY_THRESHOLD):
            print("\n\nStopping training as we have reached %2.2f%% accuracy!" %(ACCURACY_THRESHOLD*100))
            self.model.stop_training = True

acc_callback = myCallback()


def trainModel(model, epochs, optimizer, vb=1):
    cbs = [#k.callbacks.ReduceLROnPlateau(patience=5, verbose=1),
           k.callbacks.ModelCheckpoint(filepath=bestModelPath, monitor='val_loss', verbose=1, save_best_only=True)]
    batch_size = 64
    callback = myCallback()
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics='accuracy'
    )
    return model.fit(X_train, y_train,
#                      validation_data=(X_test, y_test),
                     epochs=epochs, verbose=vb,
                     validation_split=0.2,
                     batch_size=batch_size, callbacks=cbs)

def plotHistory(history):
    print("Max. Validation Accuracy",max(history.history["val_accuracy"]))
    pd.DataFrame(history.history).plot(figsize=(12,6))
    plt.show()

# %%
model_1 = k.models.Sequential([
    k.layers.Conv1D(256, 8, padding='same', activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
#     k.layers.Conv1D(256, 8, padding='same', activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Dropout(0.2),
    k.layers.MaxPooling1D(pool_size=(8)),
    k.layers.Conv1D(128, 8, padding='same', activation='relu'),
#     k.layers.Conv1D(128, 8, padding='same', activation='relu'),
#     k.layers.Conv1D(128, 8, padding='same', activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Dropout(0.2),
    k.layers.MaxPooling1D(pool_size=(5)),
#     k.layers.Conv1D(64, 8, padding='same', activation='relu'),
    k.layers.Conv1D(64, 8, padding='same', activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Flatten(),
#     k.layers.Dense(64, activation='relu'),
    k.layers.Dense(len(index_label), activation='softmax'),
])
print(model_1.summary())
model_1_history = trainModel(model=model_1, epochs=50, optimizer='adam', vb=0)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 128, 256)          262400
#
#  batch_normalization (Batch  (None, 128, 256)          1024
#  Normalization)
#
#  dropout (Dropout)           (None, 128, 256)          0
#
#  max_pooling1d (MaxPooling1  (None, 16, 256)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 16, 128)           262272
#
#  batch_normalization_1 (Bat  (None, 16, 128)           512
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 16, 128)           0
#
#  max_pooling1d_1 (MaxPoolin  (None, 3, 128)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             65600
#
#  batch_normalization_2 (Bat  (None, 3, 64)             256
#  chNormalization)
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 3)                 579
#
# =================================================================
# Total params: 592643 (2.26 MB)
# Trainable params: 591747 (2.26 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________
# None
#
# Epoch 1: val_loss improved from inf to 1.00688, saving model to ./best_model.hdf5
#
# Epoch 2: val_loss improved from 1.00688 to 0.98479, saving model to ./best_model.hdf5
#
# Epoch 3: val_loss improved from 0.98479 to 0.93623, saving model to ./best_model.hdf5
#
# Epoch 4: val_loss improved from 0.93623 to 0.89265, saving model to ./best_model.hdf5
#
# Epoch 5: val_loss improved from 0.89265 to 0.86606, saving model to ./best_model.hdf5
#
# Epoch 6: val_loss improved from 0.86606 to 0.85228, saving model to ./best_model.hdf5
#
# Epoch 7: val_loss improved from 0.85228 to 0.83186, saving model to ./best_model.hdf5
#
# Epoch 8: val_loss improved from 0.83186 to 0.81492, saving model to ./best_model.hdf5
#
# Epoch 9: val_loss improved from 0.81492 to 0.78605, saving model to ./best_model.hdf5
#
# Epoch 10: val_loss improved from 0.78605 to 0.74394, saving model to ./best_model.hdf5
#
# Epoch 11: val_loss improved from 0.74394 to 0.72163, saving model to ./best_model.hdf5
#
# Epoch 12: val_loss improved from 0.72163 to 0.71152, saving model to ./best_model.hdf5
#
# Epoch 13: val_loss improved from 0.71152 to 0.70339, saving model to ./best_model.hdf5
#
# Epoch 14: val_loss improved from 0.70339 to 0.69572, saving model to ./best_model.hdf5
#
# Epoch 15: val_loss improved from 0.69572 to 0.68859, saving model to ./best_model.hdf5
#
# Epoch 16: val_loss improved from 0.68859 to 0.68003, saving model to ./best_model.hdf5
#
# Epoch 17: val_loss improved from 0.68003 to 0.67386, saving model to ./best_model.hdf5
#
# Epoch 18: val_loss improved from 0.67386 to 0.67049, saving model to ./best_model.hdf5
#
# Epoch 19: val_loss improved from 0.67049 to 0.67022, saving model to ./best_model.hdf5
#
# Epoch 20: val_loss improved from 0.67022 to 0.66739, saving model to ./best_model.hdf5
#
# Epoch 21: val_loss improved from 0.66739 to 0.66627, saving model to ./best_model.hdf5
#
# Epoch 22: val_loss improved from 0.66627 to 0.66500, saving model to ./best_model.hdf5
#
# Epoch 23: val_loss improved from 0.66500 to 0.66394, saving model to ./best_model.hdf5
#
# Epoch 24: val_loss improved from 0.66394 to 0.66264, saving model to ./best_model.hdf5
#
# Epoch 25: val_loss did not improve from 0.66264
#
# Epoch 26: val_loss did not improve from 0.66264
#
# Epoch 27: val_loss did not improve from 0.66264
#
# Epoch 28: val_loss did not improve from 0.66264
#
# Epoch 29: val_loss did not improve from 0.66264
#
# Epoch 30: val_loss did not improve from 0.66264
#
# Epoch 31: val_loss did not improve from 0.66264
#
# Epoch 32: val_loss did not improve from 0.66264
#
# Epoch 33: val_loss did not improve from 0.66264
#
# Epoch 34: val_loss did not improve from 0.66264
#
# Epoch 35: val_loss did not improve from 0.66264
#
# Epoch 36: val_loss did not improve from 0.66264
#
# Epoch 37: val_loss did not improve from 0.66264
#
# Epoch 38: val_loss did not improve from 0.66264
#
# Epoch 39: val_loss did not improve from 0.66264
#
# Epoch 40: val_loss did not improve from 0.66264
#
# Epoch 41: val_loss did not improve from 0.66264
#
# Epoch 42: val_loss did not improve from 0.66264
#
# Epoch 43: val_loss did not improve from 0.66264
#
# Epoch 44: val_loss did not improve from 0.66264
#
# Epoch 45: val_loss did not improve from 0.66264
#
# Epoch 46: val_loss did not improve from 0.66264
#
# Epoch 47: val_loss did not improve from 0.66264
#
# Epoch 48: val_loss did not improve from 0.66264
#
# Epoch 49: val_loss did not improve from 0.66264
#
# Epoch 50: val_loss did not improve from 0.66264

# %%
plotHistory(model_1_history)
# Out:
# Max. Validation Accuracy 0.875

# %%
# evaluation
test_loss, test_acc  = k.models.load_model(bestModelPath).evaluate(X_test, y_test, batch_size=128)
print("The test Loss is :",test_loss)
print("The test Accuracy is :",test_acc*100)
# Out:
# 1/1 [==============================] - 1s 637ms/step - loss: 0.7227 - accuracy: 0.6800
# The test Loss is : 0.722731351852417
# The test Accuracy is : 68.00000071525574

# %%
model_2 = k.models.Sequential([
    k.layers.Conv1D(256, 5, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    k.layers.BatchNormalization(),
    k.layers.Dropout(0.3),
    k.layers.MaxPooling1D(pool_size=(2)),
    k.layers.Conv1D(128, 3, activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Dropout(0.3),
    k.layers.MaxPooling1D(pool_size=(3)),
    k.layers.Conv1D(64, 3, activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Flatten(),
    k.layers.Dense(32, activation='relu'),
    k.layers.Dense(len(index_label), activation='softmax'),
])
print(model_2.summary())
model_2_history = trainModel(model=model_2, epochs=100, optimizer='adam', vb=0)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 124, 256)          164096
#
#  batch_normalization_3 (Bat  (None, 124, 256)          1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 124, 256)          0
#
#  max_pooling1d_2 (MaxPoolin  (None, 62, 256)           0
#  g1D)
#
#  conv1d_4 (Conv1D)           (None, 60, 128)           98432
#
#  batch_normalization_4 (Bat  (None, 60, 128)           512
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 60, 128)           0
#
#  max_pooling1d_3 (MaxPoolin  (None, 20, 128)           0
#  g1D)
#
#  conv1d_5 (Conv1D)           (None, 18, 64)            24640
#
#  batch_normalization_5 (Bat  (None, 18, 64)            256
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_1 (Dense)             (None, 32)                36896
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 325955 (1.24 MB)
# Trainable params: 325059 (1.24 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________
# None
#
# Epoch 1: val_loss improved from inf to 1.07765, saving model to ./best_model.hdf5
#
# Epoch 2: val_loss improved from 1.07765 to 1.06015, saving model to ./best_model.hdf5
#
# Epoch 3: val_loss improved from 1.06015 to 1.03200, saving model to ./best_model.hdf5
#
# Epoch 4: val_loss improved from 1.03200 to 1.00197, saving model to ./best_model.hdf5
#
# Epoch 5: val_loss improved from 1.00197 to 0.97682, saving model to ./best_model.hdf5
#
# Epoch 6: val_loss improved from 0.97682 to 0.96447, saving model to ./best_model.hdf5
#
# Epoch 7: val_loss improved from 0.96447 to 0.93450, saving model to ./best_model.hdf5
#
# Epoch 8: val_loss improved from 0.93450 to 0.88758, saving model to ./best_model.hdf5
#
# Epoch 9: val_loss improved from 0.88758 to 0.84679, saving model to ./best_model.hdf5
#
# Epoch 10: val_loss improved from 0.84679 to 0.83293, saving model to ./best_model.hdf5
#
# Epoch 11: val_loss did not improve from 0.83293
#
# Epoch 12: val_loss did not improve from 0.83293
#
# Epoch 13: val_loss did not improve from 0.83293
#
# Epoch 14: val_loss did not improve from 0.83293
#
# Epoch 15: val_loss did not improve from 0.83293
#
# Epoch 16: val_loss did not improve from 0.83293
#
# Epoch 17: val_loss did not improve from 0.83293
#
# Epoch 18: val_loss did not improve from 0.83293
#
# Epoch 19: val_loss did not improve from 0.83293
#
# Epoch 20: val_loss did not improve from 0.83293
#
# Epoch 21: val_loss did not improve from 0.83293
#
# Epoch 22: val_loss did not improve from 0.83293
#
# Epoch 23: val_loss did not improve from 0.83293
#
# Epoch 24: val_loss did not improve from 0.83293
#
# Epoch 25: val_loss did not improve from 0.83293
#
# Epoch 26: val_loss did not improve from 0.83293
#
# Epoch 27: val_loss did not improve from 0.83293
#
# Epoch 28: val_loss did not improve from 0.83293
#
# Epoch 29: val_loss did not improve from 0.83293
#
# Epoch 30: val_loss did not improve from 0.83293
#
# Epoch 31: val_loss did not improve from 0.83293
#
# Epoch 32: val_loss did not improve from 0.83293
#
# Epoch 33: val_loss did not improve from 0.83293
#
# Epoch 34: val_loss did not improve from 0.83293
#
# Epoch 35: val_loss did not improve from 0.83293
#
# Epoch 36: val_loss did not improve from 0.83293
#
# Epoch 37: val_loss did not improve from 0.83293
#
# Epoch 38: val_loss did not improve from 0.83293
#
# Epoch 39: val_loss did not improve from 0.83293
#
# Epoch 40: val_loss did not improve from 0.83293
#
# Epoch 41: val_loss did not improve from 0.83293
#
# Epoch 42: val_loss did not improve from 0.83293
#
# Epoch 43: val_loss did not improve from 0.83293
#
# Epoch 44: val_loss did not improve from 0.83293
#
# Epoch 45: val_loss did not improve from 0.83293
#
# Epoch 46: val_loss did not improve from 0.83293
#
# Epoch 47: val_loss did not improve from 0.83293
#
# Epoch 48: val_loss did not improve from 0.83293
#
# Epoch 49: val_loss did not improve from 0.83293
#
# Epoch 50: val_loss did not improve from 0.83293
#
# Epoch 51: val_loss did not improve from 0.83293
#
# Epoch 52: val_loss did not improve from 0.83293
#
# Epoch 53: val_loss did not improve from 0.83293
#
# Epoch 54: val_loss did not improve from 0.83293
#
# Epoch 55: val_loss did not improve from 0.83293
#
# Epoch 56: val_loss did not improve from 0.83293
#
# Epoch 57: val_loss did not improve from 0.83293
#
# Epoch 58: val_loss did not improve from 0.83293
#
# Epoch 59: val_loss did not improve from 0.83293
#
# Epoch 60: val_loss did not improve from 0.83293
#
# Epoch 61: val_loss did not improve from 0.83293
#
# Epoch 62: val_loss did not improve from 0.83293
#
# Epoch 63: val_loss did not improve from 0.83293
#
# Epoch 64: val_loss did not improve from 0.83293
#
# Epoch 65: val_loss did not improve from 0.83293
#
# Epoch 66: val_loss did not improve from 0.83293
#
# Epoch 67: val_loss did not improve from 0.83293
#
# Epoch 68: val_loss did not improve from 0.83293
#
# Epoch 69: val_loss did not improve from 0.83293
#
# Epoch 70: val_loss did not improve from 0.83293
#
# Epoch 71: val_loss did not improve from 0.83293
#
# Epoch 72: val_loss did not improve from 0.83293
#
# Epoch 73: val_loss did not improve from 0.83293
#
# Epoch 74: val_loss did not improve from 0.83293
#
# Epoch 75: val_loss did not improve from 0.83293
#
# Epoch 76: val_loss did not improve from 0.83293
#
# Epoch 77: val_loss did not improve from 0.83293
#
# Epoch 78: val_loss did not improve from 0.83293
#
# Epoch 79: val_loss did not improve from 0.83293
#
# Epoch 80: val_loss did not improve from 0.83293
#
# Epoch 81: val_loss did not improve from 0.83293
#
# Epoch 82: val_loss did not improve from 0.83293
#
# Epoch 83: val_loss did not improve from 0.83293
#
# Epoch 84: val_loss did not improve from 0.83293
#
# Epoch 85: val_loss did not improve from 0.83293
#
# Epoch 86: val_loss did not improve from 0.83293
#
# Epoch 87: val_loss did not improve from 0.83293
#
# Epoch 88: val_loss did not improve from 0.83293
#
# Epoch 89: val_loss did not improve from 0.83293
#
# Epoch 90: val_loss did not improve from 0.83293
#
# Epoch 91: val_loss did not improve from 0.83293
#
# Epoch 92: val_loss did not improve from 0.83293
#
# Epoch 93: val_loss did not improve from 0.83293
#
# Epoch 94: val_loss did not improve from 0.83293
#
# Epoch 95: val_loss did not improve from 0.83293
#
# Epoch 96: val_loss did not improve from 0.83293
#
# Epoch 97: val_loss did not improve from 0.83293
#
# Epoch 98: val_loss did not improve from 0.83293
#
# Epoch 99: val_loss did not improve from 0.83293
#
# Epoch 100: val_loss did not improve from 0.83293

# %%
plotHistory(model_2_history)
# Out:
# Max. Validation Accuracy 0.8999999761581421

# %%
# evaluation
test_loss, test_acc  = k.models.load_model(bestModelPath).evaluate(X_test, y_test, batch_size=128)
print("The test Loss is :",test_loss)
print("The test Accuracy is :",test_acc*100)
# Out:
# 1/1 [==============================] - 0s 279ms/step - loss: 0.9340 - accuracy: 0.5800
# The test Loss is : 0.9339743852615356
# The test Accuracy is : 57.999998331069946

# %%
model_3 = k.models.Sequential([
    k.layers.Bidirectional(k.layers.LSTM(100, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])),

    k.layers.Bidirectional(k.layers.LSTM(128, return_sequences=False)),

    k.layers.Dense(64, activation='relu'),
    k.layers.Dropout(0.2),
    k.layers.Dense(64, activation='relu'),
    k.layers.Dropout(0.2),
    k.layers.Dense(32, activation='relu'),
    k.layers.Dense(len(index_label), activation='softmax'),
])
print(model_3.summary())
model_3_history = trainModel(model=model_3, epochs=100, optimizer='rmsprop', vb=0)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 128, 512)          788480
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 256)               656384
#  onal)
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 1467651 (5.60 MB)
# Trainable params: 1467651 (5.60 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
#
# Epoch 1: val_loss improved from inf to 1.08639, saving model to ./best_model.hdf5
#
# Epoch 2: val_loss did not improve from 1.08639
#
# Epoch 3: val_loss improved from 1.08639 to 1.00095, saving model to ./best_model.hdf5
#
# Epoch 4: val_loss did not improve from 1.00095
#
# Epoch 5: val_loss did not improve from 1.00095
#
# Epoch 6: val_loss did not improve from 1.00095
#
# Epoch 7: val_loss did not improve from 1.00095
#
# Epoch 8: val_loss improved from 1.00095 to 0.97245, saving model to ./best_model.hdf5
#
# Epoch 9: val_loss improved from 0.97245 to 0.91073, saving model to ./best_model.hdf5
#
# Epoch 10: val_loss improved from 0.91073 to 0.89360, saving model to ./best_model.hdf5
#
# Epoch 11: val_loss improved from 0.89360 to 0.83531, saving model to ./best_model.hdf5
#
# Epoch 12: val_loss did not improve from 0.83531
#
# Epoch 13: val_loss did not improve from 0.83531
#
# Epoch 14: val_loss improved from 0.83531 to 0.83177, saving model to ./best_model.hdf5
#
# Epoch 15: val_loss improved from 0.83177 to 0.72524, saving model to ./best_model.hdf5
#
# Epoch 16: val_loss did not improve from 0.72524
#
# Epoch 17: val_loss did not improve from 0.72524
#
# Epoch 18: val_loss improved from 0.72524 to 0.62818, saving model to ./best_model.hdf5
#
# Epoch 19: val_loss did not improve from 0.62818
#
# Epoch 20: val_loss did not improve from 0.62818
#
# Epoch 21: val_loss improved from 0.62818 to 0.61975, saving model to ./best_model.hdf5
#
# Epoch 22: val_loss did not improve from 0.61975
#
# Epoch 23: val_loss did not improve from 0.61975
#
# Epoch 24: val_loss did not improve from 0.61975
#
# Epoch 25: val_loss did not improve from 0.61975
#
# Epoch 26: val_loss improved from 0.61975 to 0.53213, saving model to ./best_model.hdf5
#
# Epoch 27: val_loss did not improve from 0.53213
#
# Epoch 28: val_loss did not improve from 0.53213
#
# Epoch 29: val_loss improved from 0.53213 to 0.50319, saving model to ./best_model.hdf5
#
# Epoch 30: val_loss improved from 0.50319 to 0.48314, saving model to ./best_model.hdf5
#
# Epoch 31: val_loss did not improve from 0.48314
#
# Epoch 32: val_loss did not improve from 0.48314
#
# Epoch 33: val_loss did not improve from 0.48314
#
# Epoch 34: val_loss did not improve from 0.48314
#
# Epoch 35: val_loss improved from 0.48314 to 0.47414, saving model to ./best_model.hdf5
#
# Epoch 36: val_loss improved from 0.47414 to 0.46780, saving model to ./best_model.hdf5
#
# Epoch 37: val_loss did not improve from 0.46780
#
# Epoch 38: val_loss did not improve from 0.46780
#
# Epoch 39: val_loss improved from 0.46780 to 0.38030, saving model to ./best_model.hdf5
#
# Epoch 40: val_loss did not improve from 0.38030
#
# Epoch 41: val_loss did not improve from 0.38030
#
# Epoch 42: val_loss did not improve from 0.38030
#
# Epoch 43: val_loss did not improve from 0.38030
#
# Epoch 44: val_loss did not improve from 0.38030
#
# Epoch 45: val_loss did not improve from 0.38030
#
# Epoch 46: val_loss did not improve from 0.38030
#
# Epoch 47: val_loss did not improve from 0.38030
#
# Epoch 48: val_loss did not improve from 0.38030
#
# Epoch 49: val_loss did not improve from 0.38030
#
# Epoch 50: val_loss did not improve from 0.38030
#
# Epoch 51: val_loss did not improve from 0.38030
#
# Epoch 52: val_loss did not improve from 0.38030
#
# Epoch 53: val_loss did not improve from 0.38030
#
# Epoch 54: val_loss did not improve from 0.38030
#
# Epoch 55: val_loss did not improve from 0.38030
#
# Epoch 56: val_loss did not improve from 0.38030
#
# Epoch 57: val_loss did not improve from 0.38030
#
# Epoch 58: val_loss did not improve from 0.38030
#
# Epoch 59: val_loss did not improve from 0.38030
#
# Epoch 60: val_loss did not improve from 0.38030
#
# Epoch 61: val_loss did not improve from 0.38030
#
# Epoch 62: val_loss did not improve from 0.38030
#
# Epoch 63: val_loss did not improve from 0.38030
#
# Epoch 64: val_loss did not improve from 0.38030
#
# Epoch 65: val_loss did not improve from 0.38030
#
# Epoch 66: val_loss did not improve from 0.38030
#
# Epoch 67: val_loss did not improve from 0.38030
#
# Epoch 68: val_loss did not improve from 0.38030
#
# Epoch 69: val_loss did not improve from 0.38030
#
# Epoch 70: val_loss did not improve from 0.38030
#
# Epoch 71: val_loss did not improve from 0.38030
#
# Epoch 72: val_loss did not improve from 0.38030
#
# Epoch 73: val_loss did not improve from 0.38030
#
# Epoch 74: val_loss did not improve from 0.38030
#
# Epoch 75: val_loss did not improve from 0.38030
#
# Epoch 76: val_loss did not improve from 0.38030
#
# Epoch 77: val_loss did not improve from 0.38030
#
# Epoch 78: val_loss did not improve from 0.38030
#
# Epoch 79: val_loss did not improve from 0.38030
#
# Epoch 80: val_loss did not improve from 0.38030
#
# Epoch 81: val_loss did not improve from 0.38030
#
# Epoch 82: val_loss did not improve from 0.38030
#
# Epoch 83: val_loss did not improve from 0.38030
#
# Epoch 84: val_loss did not improve from 0.38030
#
# Epoch 85: val_loss did not improve from 0.38030
#
# Epoch 86: val_loss did not improve from 0.38030
#
# Epoch 87: val_loss did not improve from 0.38030
#
# Epoch 88: val_loss did not improve from 0.38030
#
# Epoch 89: val_loss did not improve from 0.38030
#
# Epoch 90: val_loss did not improve from 0.38030
#
# Epoch 91: val_loss did not improve from 0.38030
#
# Epoch 92: val_loss did not improve from 0.38030
#
# Epoch 93: val_loss did not improve from 0.38030
#
# Epoch 94: val_loss did not improve from 0.38030
#
# Epoch 95: val_loss did not improve from 0.38030
#
# Epoch 96: val_loss did not improve from 0.38030
#
# Epoch 97: val_loss did not improve from 0.38030
#
# Epoch 98: val_loss did not improve from 0.38030
#
# Epoch 99: val_loss did not improve from 0.38030
#
# Epoch 100: val_loss did not improve from 0.38030

# %%
plotHistory(model_3_history)
# Out:
# Max. Validation Accuracy 0.8500000238418579
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-291e6bd09142> in <cell line: 1>()
# ----> 1 plotHistory(model_3_history)
#
# <ipython-input-32-b7fd412dd4ae> in plotHistory(history)
#      29     print("Max. Validation Accuracy",max(history.history["val_accuracy"]))
#      30     pd.DataFrame(history.history).plot(figsize=(12,6))
# ---> 31     plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     444     """
#     445     _warn_if_gui_out_of_main_thread()
# --> 446     return _get_backend_mod().show(*args, **kwargs)
#     447
#     448
#
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2364                 # force the figure dpi to 72), so we need to set it again here.
#    2365                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366                     result = print_method(
#    2367                         filename,
#    2368                         facecolor=facecolor,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2230                 "bbox_inches_restore"}
#    2231             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     510
#     511     def print_to_buffer(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     455         *pil_kwargs* and *metadata* are forwarded).
#     456         """
# --> 457         FigureCanvasAgg.draw(self)
#     458         mpl.image.imsave(
#     459             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     398              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399               else nullcontext()):
# --> 400             self.figure.draw(self.renderer)
#     401             # A GUI class may be need to update a window using this draw, so
#     402             # don't forget to call the superclass.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3138
#    3139             self.patch.draw(renderer)
# -> 3140             mimage._draw_list_compositing_images(
#    3141                 renderer, self, artists, self.suppressComposite)
#    3142
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3026                 artists.remove(spine)
#    3027
# -> 3028         self._update_title_position(renderer)
#    3029
#    3030         if not self.axison:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2961                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2962                         or ax.xaxis.get_label_position() == 'top'):
# -> 2963                     bb = ax.xaxis.get_tightbbox(renderer)
#    2964                 if bb is None:
#    2965                     if 'outline' in ax.spines:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1323         ticks_to_draw = self._update_ticks()
#    1324
# -> 1325         self._update_label_position(renderer)
#    1326
#    1327         # go back to just this axis's tick labels
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2302         # get bounding boxes for this axis and any siblings
#    2303         # that have been set by `fig.align_xlabels()`
# -> 2304         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2305
#    2306         x, y = self.label.get_position()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2097         for ax in grouper.get_siblings(self.axes):
#    2098             axis = getattr(ax, f"{axis_name}axis")
# -> 2099             ticks_to_draw = axis._update_ticks()
#    2100             tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2101             bboxes.extend(tlb)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1268             tick.set_label1(label)
#    1269             tick.set_label2(label)
# -> 1270         minor_locs = self.get_minorticklocs()
#    1271         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1272         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in get_minorticklocs(self)
#    1497             # rtol for np.isclose.
#    1498             tol = (hi - lo) * 1e-5
# -> 1499             mask = np.isclose(tr_minor_locs[:, None], tr_major_locs[None, :],
#    1500                               atol=tol, rtol=0).any(axis=1)
#    1501             minor_locs = minor_locs[~mask]
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _any(a, axis, dtype, out, keepdims, where)
#      53     return umr_prod(a, axis, dtype, out, keepdims, initial, where)
#      54
# ---> 55 def _any(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      56     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      57     if where is True:
#
# KeyboardInterrupt:

# %%
# evaluation
test_loss, test_acc  = k.models.load_model(bestModelPath).evaluate(X_test, y_test, batch_size=128)
print("The test Loss is :",test_loss)
print("The test Accuracy is :",test_acc*100)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.7486 - accuracy: 0.7400
# The test Loss is : 0.7485730648040771
# The test Accuracy is : 74.00000095367432

# %%
# make features 3D with last dim as 1 for 1DConv
X_train = np.expand_dims(X_train, axis=3)
X_test = np.expand_dims(X_test, axis=3)
X_train.shape
# Out:
# (200, 128, 128, 1)

# %%
model_4 = k.models.Sequential([
    k.layers.Conv2D(50, (5,5), activation='relu', input_shape=(X_train.shape[1], X_train.shape[2], 1)),
    k.layers.BatchNormalization(),
    k.layers.MaxPooling2D(pool_size=(2)),
    k.layers.Dropout(0.3),
    k.layers.Conv2D(128, (3,3), activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.MaxPooling2D(pool_size=(2)),
    k.layers.Dropout(0.3),
    k.layers.Conv2D(64, (3,3), padding='valid', activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Flatten(),
    k.layers.Dense(64, activation='relu'),
    k.layers.Dense(len(index_label), activation='softmax'),

])
print(model_4.summary())
model_4_history = trainModel(model=model_4, epochs=50, optimizer='adam', vb=0)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 124, 124, 50)      1300
#
#  batch_normalization_6 (Bat  (None, 124, 124, 50)      200
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 62, 62, 50)        0
#  D)
#
#  dropout_6 (Dropout)         (None, 62, 62, 50)        0
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 128)       57728
#
#  batch_normalization_7 (Bat  (None, 60, 60, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 30, 30, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        73792
#
#  batch_normalization_8 (Bat  (None, 28, 28, 64)        256
#  chNormalization)
#
#  flatten_2 (Flatten)         (None, 50176)             0
#
#  dense_7 (Dense)             (None, 64)                3211328
#
#  dense_8 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 3345311 (12.76 MB)
# Trainable params: 3344827 (12.76 MB)
# Non-trainable params: 484 (1.89 KB)
# _________________________________________________________________
# None
#
# Epoch 1: val_loss improved from inf to 1.12103, saving model to ./best_model.hdf5
#
# Epoch 2: val_loss did not improve from 1.12103
#
# Epoch 3: val_loss improved from 1.12103 to 1.10521, saving model to ./best_model.hdf5
#
# Epoch 4: val_loss improved from 1.10521 to 1.08497, saving model to ./best_model.hdf5
#
# Epoch 5: val_loss improved from 1.08497 to 1.07376, saving model to ./best_model.hdf5
#
# Epoch 6: val_loss improved from 1.07376 to 1.06638, saving model to ./best_model.hdf5
#
# Epoch 7: val_loss did not improve from 1.06638
#
# Epoch 8: val_loss did not improve from 1.06638
#
# Epoch 9: val_loss did not improve from 1.06638
#
# Epoch 10: val_loss did not improve from 1.06638
#
# Epoch 11: val_loss did not improve from 1.06638
#
# Epoch 12: val_loss did not improve from 1.06638
#
# Epoch 13: val_loss did not improve from 1.06638
#
# Epoch 14: val_loss did not improve from 1.06638
#
# Epoch 15: val_loss did not improve from 1.06638
#
# Epoch 16: val_loss did not improve from 1.06638
#
# Epoch 17: val_loss did not improve from 1.06638
#
# Epoch 18: val_loss did not improve from 1.06638
#
# Epoch 19: val_loss did not improve from 1.06638
#
# Epoch 20: val_loss did not improve from 1.06638
#
# Epoch 21: val_loss did not improve from 1.06638
#
# Epoch 22: val_loss did not improve from 1.06638
#
# Epoch 23: val_loss did not improve from 1.06638
#
# Epoch 24: val_loss did not improve from 1.06638
#
# Epoch 25: val_loss did not improve from 1.06638
#
# Epoch 26: val_loss did not improve from 1.06638
#
# Epoch 27: val_loss did not improve from 1.06638
#
# Epoch 28: val_loss did not improve from 1.06638
#
# Epoch 29: val_loss did not improve from 1.06638
#
# Epoch 30: val_loss did not improve from 1.06638
#
# Epoch 31: val_loss did not improve from 1.06638
#
# Epoch 32: val_loss did not improve from 1.06638
#
# Epoch 33: val_loss did not improve from 1.06638
#
# Epoch 34: val_loss did not improve from 1.06638
#
# Epoch 35: val_loss did not improve from 1.06638
#
# Epoch 36: val_loss did not improve from 1.06638
#
# Epoch 37: val_loss did not improve from 1.06638
#
# Epoch 38: val_loss did not improve from 1.06638
#
# Epoch 39: val_loss did not improve from 1.06638
#
# Epoch 40: val_loss did not improve from 1.06638
#
# Epoch 41: val_loss did not improve from 1.06638
#
# Epoch 42: val_loss did not improve from 1.06638
#
# Epoch 43: val_loss did not improve from 1.06638
#
# Epoch 44: val_loss did not improve from 1.06638
#
# Epoch 45: val_loss did not improve from 1.06638
#
# Epoch 46: val_loss did not improve from 1.06638
#
# Epoch 47: val_loss did not improve from 1.06638
#
# Epoch 48: val_loss did not improve from 1.06638
#
# Epoch 49: val_loss did not improve from 1.06638
#
# Epoch 50: val_loss did not improve from 1.06638

# %%
plotHistory(model_4_history)
# Out:
# Max. Validation Accuracy 0.5

# %%
# evaluation
test_loss, test_acc  = k.models.load_model(bestModelPath).evaluate(X_test, y_test, batch_size=128)
print("The test Loss is :",test_loss)
print("The test Accuracy is :",test_acc*100)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 1.0763 - accuracy: 0.3000
# The test Loss is : 1.0762717723846436
# The test Accuracy is : 30.000001192092896

# %%
inputShape = (X_train.shape[1], X_train.shape[2], 1)
model_5 = k.models.Sequential([
    k.layers.TimeDistributed(k.layers.Conv1D(100, 5), input_shape=inputShape),
    k.layers.TimeDistributed(k.layers.BatchNormalization()),
    k.layers.TimeDistributed(k.layers.MaxPooling1D((2))),
    k.layers.TimeDistributed(k.layers.Dropout(0.3)),

    k.layers.TimeDistributed(k.layers.Conv1D(128, 3), input_shape=inputShape),
    k.layers.TimeDistributed(k.layers.BatchNormalization()),
    k.layers.TimeDistributed(k.layers.MaxPooling1D((2))),
    k.layers.TimeDistributed(k.layers.Dropout(0.3)),
    k.layers.TimeDistributed(k.layers.Flatten())

], name="conv_3d7")

model_5.add(k.layers.Bidirectional(k.layers.LSTM(256, return_sequences=True)))
model_5.add(k.layers.Dropout(0.3))

model_5.add(k.layers.Bidirectional(k.layers.LSTM(128)))
model_5.add(k.layers.Dropout(0.3))

model_5.add(k.layers.Dense(64, activation='relu'))
model_5.add(k.layers.Dropout(0.3))

model_5.add(k.layers.Dense(len(index_label), activation='softmax'))

print(model_5.summary())
model_5_history = trainModel(model=model_5, epochs=100, optimizer='adam', vb=0)
# Out:
# Model: "conv_3d7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDist  (None, 128, 124, 100)     600
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 128, 124, 100)     400
#  stributed)
#
#  time_distributed_2 (TimeDi  (None, 128, 62, 100)      0
#  stributed)
#
#  time_distributed_3 (TimeDi  (None, 128, 62, 100)      0
#  stributed)
#
#  time_distributed_4 (TimeDi  (None, 128, 60, 128)      38528
#  stributed)
#
#  time_distributed_5 (TimeDi  (None, 128, 60, 128)      512
#  stributed)
#
#  time_distributed_6 (TimeDi  (None, 128, 30, 128)      0
#  stributed)
#
#  time_distributed_7 (TimeDi  (None, 128, 30, 128)      0
#  stributed)
#
#  time_distributed_8 (TimeDi  (None, 128, 3840)         0
#  stributed)
#
#  bidirectional_2 (Bidirecti  (None, 128, 512)          8390656
#  onal)
#
#  dropout_10 (Dropout)        (None, 128, 512)          0
#
#  bidirectional_3 (Bidirecti  (None, 256)               656384
#  onal)
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_9 (Dense)             (None, 64)                16448
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_10 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 9103723 (34.73 MB)
# Trainable params: 9103267 (34.73 MB)
# Non-trainable params: 456 (1.78 KB)
# _________________________________________________________________
# None
#
# Epoch 1: val_loss improved from inf to 1.11871, saving model to ./best_model.hdf5
#
# Epoch 2: val_loss improved from 1.11871 to 1.08950, saving model to ./best_model.hdf5
#
# Epoch 3: val_loss did not improve from 1.08950
#
# Epoch 4: val_loss did not improve from 1.08950
#
# Epoch 5: val_loss did not improve from 1.08950
#
# Epoch 6: val_loss did not improve from 1.08950
#
# Epoch 7: val_loss did not improve from 1.08950
#
# Epoch 8: val_loss did not improve from 1.08950
#
# Epoch 9: val_loss did not improve from 1.08950
#
# Epoch 10: val_loss did not improve from 1.08950
#
# Epoch 11: val_loss did not improve from 1.08950
#
# Epoch 12: val_loss did not improve from 1.08950
#
# Epoch 13: val_loss did not improve from 1.08950
#
# Epoch 14: val_loss did not improve from 1.08950
#
# Epoch 15: val_loss did not improve from 1.08950
#
# Epoch 16: val_loss did not improve from 1.08950
#
# Epoch 17: val_loss did not improve from 1.08950
#
# Epoch 18: val_loss did not improve from 1.08950
#
# Epoch 19: val_loss did not improve from 1.08950
#
# Epoch 20: val_loss did not improve from 1.08950
#
# Epoch 21: val_loss did not improve from 1.08950
#
# Epoch 22: val_loss did not improve from 1.08950
#
# Epoch 23: val_loss did not improve from 1.08950
#
# Epoch 24: val_loss did not improve from 1.08950
#
# Epoch 25: val_loss did not improve from 1.08950
#
# Epoch 26: val_loss did not improve from 1.08950
#
# Epoch 27: val_loss did not improve from 1.08950
#
# Epoch 28: val_loss did not improve from 1.08950
#
# Epoch 29: val_loss did not improve from 1.08950
#
# Epoch 30: val_loss did not improve from 1.08950
#
# Epoch 31: val_loss did not improve from 1.08950
#
# Epoch 32: val_loss did not improve from 1.08950
#
# Epoch 33: val_loss did not improve from 1.08950
#
# Epoch 34: val_loss did not improve from 1.08950
#
# Epoch 35: val_loss did not improve from 1.08950
#
# Epoch 36: val_loss did not improve from 1.08950
#
# Epoch 37: val_loss did not improve from 1.08950
#
# Epoch 38: val_loss did not improve from 1.08950
#
# Epoch 39: val_loss did not improve from 1.08950
#
# Epoch 40: val_loss did not improve from 1.08950
#
# Epoch 41: val_loss did not improve from 1.08950
#
# Epoch 42: val_loss did not improve from 1.08950
#
# Epoch 43: val_loss did not improve from 1.08950
#
# Epoch 44: val_loss did not improve from 1.08950
#
# Epoch 45: val_loss did not improve from 1.08950
#
# Epoch 46: val_loss did not improve from 1.08950
#
# Epoch 47: val_loss did not improve from 1.08950
#
# Epoch 48: val_loss did not improve from 1.08950
#
# Epoch 49: val_loss did not improve from 1.08950

# %%
plotHistory(model_5_history)

# %%
# evaluation
test_loss, test_acc  = k.models.load_model(bestModelPath).evaluate(X_test, y_test, batch_size=128)
print("The test Loss is :",test_loss)
print("The test Accuracy is :",test_acc*100)

# %%
#Model using Image Data

# %%
modelPath = './best_model.hdf5'
ACCURACY_THRESHOLD = 0.95

class myCallback(k.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('val_accuracy') > ACCURACY_THRESHOLD):
            print("\n\nStopping training as we have reached %2.2f%% accuracy!" %(ACCURACY_THRESHOLD*100))
            self.model.stop_training = True

acc_callback = myCallback()

cbs = [#k.callbacks.ReduceLROnPlateau(patience=3, verbose=1),
       k.callbacks.ModelCheckpoint(filepath=modelPath, monitor='val_loss', verbose=1, save_best_only=True)]

def trainImgModel(model, epochs, optimizer, vb=1):
    batch_size = 64
    callback = myCallback()
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics='accuracy'
    )
    return model.fit(X_train_img, y_train,
                     validation_data=(X_test_img, y_test), epochs=epochs, verbose=vb,
                     batch_size=batch_size, callbacks=cbs)

def plotHistory(history):
    print("Max. Validation Accuracy",max(history.history["val_accuracy"]))
    pd.DataFrame(history.history).plot(figsize=(12,6))
    plt.show()

# %%
model_6 = k.models.Sequential([
    k.layers.Conv2D(256, 3, activation='relu', input_shape=(128, 128, 3)),
    k.layers.BatchNormalization(),
    k.layers.MaxPooling2D(pool_size=(2)),
    k.layers.Dropout(0.2),
    k.layers.Conv2D(128, 3, activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.MaxPooling2D(pool_size=(2)),
    k.layers.Dropout(0.2),
    k.layers.Conv2D(64, 3, padding='same', activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Flatten(),
    k.layers.Dense(64, activation='relu'),
    k.layers.Dense(len(index_label), activation='softmax'),

])
print(model_6.summary())
model_6_history = trainImgModel(model=model_6, epochs=100, optimizer='rmsprop', vb=0)

# %%
plotHistory(model_6_history)

# %%
# model evaluation
test_loss, test_acc  = k.models.load_model(bestModelPath).evaluate(X_test_img, y_test, batch_size=128)
print("The test Loss is :",test_loss)
print("The test Accuracy is :",test_acc*1
